# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.model_selection import cross_val_score, train_test_split, cross_val_predict
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

# %%
# reading the database
data = pd.read_csv("fifa_attendance.csv", index_col=0)

# printing the top 10 rows
display(data.head(10))
# Out:
#                                         Total attendance  \
# FIFA football World Cup games 1930-2018
# 2018 Russia                                    3,031,768
# 2014 Brazil                                    3,441,450
# 2010 South Africa                              3,167,984
# 2006 Germany                                   3,367,000
# 2002 Japan / South Korea                       2,724,604
# 1998 France                                    2,859,234
# 1994 USA                                       3,568,567
# 1990 Italy                                     2,527,348
# 1986 Mexico                                    2,407,431
# 1982 Spain                                     1,856,277
#
#                                         Average attendance per game
# FIFA football World Cup games 1930-2018
# 2018 Russia                                                  47,371
# 2014 Brazil                                                  53,772
# ...

# %%
df1=pd.read_csv("fifa_attendance.csv")
print("First dataframe is:")
print(df1)
# Out:
# First dataframe is:
#    FIFA football World Cup games 1930-2018 Total attendance  \
# 0                              2018 Russia        3,031,768
# 1                              2014 Brazil        3,441,450
# 2                        2010 South Africa        3,167,984
# 3                             2006 Germany        3,367,000
# 4                 2002 Japan / South Korea        2,724,604
# 5                              1998 France        2,859,234
# 6                                 1994 USA        3,568,567
# 7                               1990 Italy        2,527,348
# 8                              1986 Mexico        2,407,431
# 9                               1982 Spain        1,856,277
# 10                          1978 Argentina        1,610,215
# 11                            1974 Germany        1,774,022
# 12                             1970 Mexico        1,673,975
# 13                            1966 England        1,614,677
# ...

# %%
df2=pd.read_csv("funded.csv")
print("second dataframe is:")
print(df2)
# Out:
# second dataframe is:
#    FIFA football World Cup games 1930-2018 total funded  \
# 0                              2018 Russia  791,000,000
# 1                              2014 Brazil  576,000,000
# 2                        2010 South Africa  420,000,000
# 3                             2006 Germany  266,000,000
# 4                 2002 Japan / South Korea  156,500,000
# 5                              1998 France  103,000,000
# 6                                 1994 USA   71,000,000
# 7                               1990 Italy   54,000,000
# 8                              1986 Mexico   26,000,000
# 9                               1982 Spain   20,000,000
# 10                          1978 Argentina   18,000,000
# 11                            1974 Germany   17,000,000
# 12                             1970 Mexico   15,000,000
# 13                            1966 England   13,000,000
# 14                              1962 Chile   11,000,000
# ...

# %%
#Merge both datasets in an outer join 
df3=pd.merge(df1,df2,how="outer",left_on="FIFA football World Cup games 1930-2018", right_on="FIFA football World Cup games 1930-2018",suffixes=("_left","_right"))
print("Merged dataframe is:")
print(df3)
# Out:
# Merged dataframe is:
#    FIFA football World Cup games 1930-2018 Total attendance  \
# 0                              2018 Russia        3,031,768
# 1                              2014 Brazil        3,441,450
# 2                        2010 South Africa        3,167,984
# 3                             2006 Germany        3,367,000
# 4                 2002 Japan / South Korea        2,724,604
# 5                              1998 France        2,859,234
# 6                                 1994 USA        3,568,567
# 7                               1990 Italy        2,527,348
# 8                              1986 Mexico        2,407,431
# 9                               1982 Spain        1,856,277
# 10                          1978 Argentina        1,610,215
# 11                            1974 Germany        1,774,022
# 12                             1970 Mexico        1,673,975
# 13                            1966 England        1,614,677
# ...

# %%
# reading the database
data = pd.read_csv("fifa_attendance.csv")
data = data.applymap(lambda x: str(x.replace(',','')))
data['Total attendance'] = data['Total attendance'].astype(int)
data['Average attendance per game'] = data['Average attendance per game'].astype(int)

# %%
data.dtypes
# Out:
# FIFA football World Cup games 1930-2018    object
# Total attendance                            int64
# Average attendance per game                 int64
# dtype: object

# %%
# Scatter plot with data
plt.figure(figsize=(10,15))
plt.scatter(data['Total attendance'], data['Average attendance per game'])
# Adding Title to the Plot
plt.title("Average and total attendance at FIFA football World Cup games 1930-2018")
 
# Setting the X and Y labels
plt.xlabel('Total attendance')
plt.ylabel('Average attendance per game')
plt.xticks(rotation = 45)
plt.show()

# %%
data = pd.read_csv("fifa_attendance.csv")
# Bar chart with data
plt.figure(figsize=(10,15))
plt.bar(data['FIFA football World Cup games 1930-2018'],data['Average attendance per game'])
plt.title("Average attendance at each world cup")
 
# Setting the X and Y labels
plt.xlabel('Average attendance per game')
plt.ylabel('FIFA football World Cup games 1930-2018')
plt.xticks(rotation = 45)

# Adding the legends
plt.show()

# %%
# reading the database
data = pd.read_csv("fifa_attendance.csv")
data = data.applymap(lambda x: str(x.replace(',','')))
data['Total attendance'] = data['Total attendance'].astype(int)
data['Average attendance per game'] = data['Average attendance per game'].astype(int)

# %%
data.dtypes
# Out:
# FIFA football World Cup games 1930-2018    object
# Total attendance                            int64
# Average attendance per game                 int64
# dtype: object

# %%
plt.figure(figsize=[10,8])
n, bins, patches = plt.hist(x=data["Total attendance"], bins=8, color='#0504aa',alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.xticks(bins)
plt.yticks(fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.title('Histogram ',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.scatterplot(x='Total attendance', y='Average attendance per game', data=data, hue='FIFA football World Cup games 1930-2018')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.histplot(x='Average attendance per game', data=data, kde=True, hue='FIFA football World Cup games 1930-2018')
plt.xticks(rotation = 45)

plt.show()

# %%
# creating dataframe with fifa details
dataframe = pd.DataFrame({'Total funded': [791000000, 576000000, 420000000, 266000000],
                          'World cup year': ['2018', '2014', '2010', '2006'],
                          'winning team prize money': [38000000, 35000000, 30000000, 20000000],})
# group by world cup year
print(dataframe.groupby('World cup year').first())
print("---------------------------------")
# group by name with winning team prize money sum
print(dataframe.groupby('World cup year')['winning team prize money'].sum())
# Out:
#                 Total funded  winning team prize money
# World cup year
# 2006               266000000                  20000000
# 2010               420000000                  30000000
# 2014               576000000                  35000000
# 2018               791000000                  38000000
# ---------------------------------
# World cup year
# 2006    20000000
# 2010    30000000
# 2014    35000000
# 2018    38000000
# Name: winning team prize money, dtype: int64

# %%
df3.dtypes
# Out:
# FIFA football World Cup games 1930-2018    object
# Total attendance                           object
# Average attendance per game                object
# total funded                               object
# winning team prize money                   object
# dtype: object

# %%
df3.columns
# Out:
# Index(['FIFA football World Cup games 1930-2018', 'Total attendance',
#        'Average attendance per game', 'total funded',
#        'winning team prize money'],
#       dtype='object')

# %%
df3 = df3.applymap(lambda x: str(x.replace(',','')))
df3['Total attendance'] = df3['Total attendance'].astype(int)
df3['Average attendance per game'] = df3['Average attendance per game'].astype(int)
df3['total funded'] = df3['total funded'].astype(int)
df3['winning team prize money'] = df3['winning team prize money'].astype(int)

# %%
df3.dtypes
# Out:
# FIFA football World Cup games 1930-2018    object
# Total attendance                            int64
# Average attendance per game                 int64
# total funded                                int64
# winning team prize money                    int64
# dtype: object

# %%
#split dataset in features and target variable
feature_cols = ["total funded"]
lable = ["winning team prize money"]
x = df3[feature_cols] # Features
y = df3[lable] # Target variable

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=16)

# %%
from sklearn import metrics
from sklearn.linear_model import LinearRegression

regressor = LinearRegression().fit(x_train, y_train)

y_pred = regressor.predict(x_test)

print(regressor.score(x_test, y_test))
# Out:
# 0.8768336080965257

# %%
#split dataset in features and target variable
feature_cols = ["winning team prize money"]
lable = ["total funded"]
x = df3[feature_cols] # Features
y = df3[lable] # Target variable

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=16)

# %%
from sklearn import metrics
from sklearn.linear_model import LinearRegression

regressor = LinearRegression().fit(x_train, y_train)

y_pred = regressor.predict(x_test)

print(regressor.score(x_test, y_test))
# Out:
# 0.7946871256552213

# %%
plt.figure(figsize=(15,10))
# reading the database
data = pd.read_csv("funded.csv")
 
# draw lineplot
sns.lineplot(x="FIFA football World Cup games 1930-2018", y="total funded", data=data)
 
# setting the title using Matplotlib
plt.title('Total funded at each world cup')
plt.xticks(rotation = 45)

plt.show()
